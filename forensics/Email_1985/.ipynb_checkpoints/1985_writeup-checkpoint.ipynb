# %% [markdown]
# # Challenge: 1985
# **CTF**: BuckeyeCTF 2025
# **Category**: Web
# **Difficulty**: Beginner
# **Date Solved**: Nov 7, 2025
#
# ## Challenge Description
# This is a good forensics challenge to start with.
#
# I found this old email in my inbox from 1985, can you help me figure out what it means?
#
#
# ## Given Files
#
# [email.txt](email.txt)
#
# ## Email.txt Contents

# %% [raw]
# Hey man, I wrote you that flag printer you asked for:
#
#  begin 755 FLGPRNTR.COM
#  MOAP!@#PD=`:`-"I&Z_6Z'`&T"<TAP[1,,,#-(4A)7DQ1;AM.=5,:7W5_61EU
#  ;:T1U&4=?1AY>&EAU95AU3AE)&D=:&T9O6%<D
#  `
#  end

# %% [markdown]
# ## Solution
#
# From the contents of the email.txt file, you can see the string `FLGPRNTR.COM`
#
# The contents of the body
